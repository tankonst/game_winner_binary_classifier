# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi']= 100
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data_log_reg = pd.read_csv('new_feat_train_small.csv', index_col ='match_id_hash')
test_data =  pd.read_csv('new_feat_test_small.csv', index_col ='match_id_hash')
# #small set
#data = pd.read_csv(r'C:\Users\Tatiana\Documents\Programming\MLcourse competition\new_feat_train_small.csv', index_col ='match_id_hash')
target =  pd.read_csv('/Users/m/Insight/MLcourse/Dota/targets_plus.csv', index_col='match_id_hash')
y = target['radiant_win']
#y = y.apply(lambda x: int(x))
# data = data.drop(columns = ['positions'])
data_log_reg.head()
# Out:
#                                   d_dead  r_dead  d_health_avg  r_health_avg  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a       0       0      0.954967      0.715500
# b9c57c450ce74a2af79c9ce96fac144d       0       0      0.764778      0.846735
# 6db558535151ea18ca70a6892197db41       0       0      0.989032      0.989333
# 46a0ddce8f7ed2a8d9bd5edcbb925682       0       0      0.869557      0.955818
# b1b35ff97723d9b7ade1c9c3cf48f770       0       0      0.808481      0.735127
#
#                                   r1_in_d_base  d1_in_r_base  r1_in_r_base  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a             0             0             0
# b9c57c450ce74a2af79c9ce96fac144d             0             0             1
# 6db558535151ea18ca70a6892197db41             0             0             0
# 46a0ddce8f7ed2a8d9bd5edcbb925682             0             0             0
# b1b35ff97723d9b7ade1c9c3cf48f770             0             0             0
#
#                                   d1_in_d_base  r2_in_d_base  d2_in_r_base  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a             0             0             0
# b9c57c450ce74a2af79c9ce96fac144d             0             0             0
# 6db558535151ea18ca70a6892197db41             1             0             0
# 46a0ddce8f7ed2a8d9bd5edcbb925682             0             0             0
# b1b35ff97723d9b7ade1c9c3cf48f770             0             0             0
#
#                                       ...        log_r_creeps_stacked  \
# match_id_hash                         ...
# a400b8f29dece5f4d266f49f1ae2e98a      ...                    0.000000
# b9c57c450ce74a2af79c9ce96fac144d      ...                    1.098612
# 6db558535151ea18ca70a6892197db41      ...                    0.000000
# 46a0ddce8f7ed2a8d9bd5edcbb925682      ...                    0.000000
# b1b35ff97723d9b7ade1c9c3cf48f770      ...                    0.000000
#
#                                   log_d_creeps_stacked  log_r_camps_stacked  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a              0.000000             0.000000
# b9c57c450ce74a2af79c9ce96fac144d              1.386294             0.693147
# 6db558535151ea18ca70a6892197db41              0.000000             0.000000
# 46a0ddce8f7ed2a8d9bd5edcbb925682              1.945910             0.000000
# b1b35ff97723d9b7ade1c9c3cf48f770              1.098612             0.000000
#
#                                   log_d_camps_stacked  log_r_rune_pickups  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a             0.000000            1.098612
# b9c57c450ce74a2af79c9ce96fac144d             1.098612            2.639057
# 6db558535151ea18ca70a6892197db41             0.000000            1.386294
# 46a0ddce8f7ed2a8d9bd5edcbb925682             1.098612            2.639057
# b1b35ff97723d9b7ade1c9c3cf48f770             0.693147            2.484907
#
#                                   log_d_rune_pickups  log_r_sen_placed  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a            2.079442          0.000000
# b9c57c450ce74a2af79c9ce96fac144d            2.708050          1.386294
# 6db558535151ea18ca70a6892197db41            0.693147          0.000000
# 46a0ddce8f7ed2a8d9bd5edcbb925682            2.484907          0.000000
# b1b35ff97723d9b7ade1c9c3cf48f770            2.197225          0.000000
#
#                                   log_d_sen_placed  log_chat_len  \
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a          0.000000      2.484907
# b9c57c450ce74a2af79c9ce96fac144d          1.098612      2.397895
# 6db558535151ea18ca70a6892197db41          0.000000      0.000000
# 46a0ddce8f7ed2a8d9bd5edcbb925682          0.000000      1.609438
# b1b35ff97723d9b7ade1c9c3cf48f770          0.000000      1.386294
#
#                                   log_game_time
# match_id_hash
# a400b8f29dece5f4d266f49f1ae2e98a       5.049856
# b9c57c450ce74a2af79c9ce96fac144d       6.490724
# 6db558535151ea18ca70a6892197db41       3.091042
# 46a0ddce8f7ed2a8d9bd5edcbb925682       6.357842
# b1b35ff97723d9b7ade1c9c3cf48f770       6.118097
#
# [5 rows x 120 columns]

# %%
# smaller dataset

#col_to_drop = ['r_deaths', 'd_deaths','log_chat_len','log_game_time','game_mode','lobby_type']
col_to_drop = ['log_chat_len','log_game_time','game_mode','lobby_type']
# hero_id_bool = ['r1_hero_id_bool', 'r2_hero_id_bool', 'r3_hero_id_bool',
#        'r4_hero_id_bool', 'r5_hero_id_bool', 'd1_hero_id_bool',
#        'd2_hero_id_bool', 'd3_hero_id_bool', 'd4_hero_id_bool','d5_hero_id_bool']
# col_to_drop +=hero_id_bool
data_log_reg.drop(col_to_drop,axis=1,inplace=True)

# %%
cat_feats = ['r_in_d_base', 'd_in_r_base','r_firstblood_claimed','d_firstblood_claimed', 'r_in_r_base', 'd_in_d_base']
#cat_feats = ['game_mode','lobby_type', 'r_in_d_base', 'd_in_r_base','r_firstblood_claimed','d_firstblood_claimed', 'r_in_r_base', 'd_in_d_base']
# boolean_cols = ['boolean_r_ability_level','boolean_d_ability_level','boolean_r_kills','boolean_d_kills',
#                 'boolean_r_assists','boolean_d_assists','boolean_r_deaths','boolean_d_deaths','boolean_r_sen_placed',
#                'boolean_d_sen_placed']
# cat_feats += boolean_cols

num_feats = [col for col in data_log_reg.columns if col not in cat_feats]
numerical_columns =[]
for j in range(len(data_log_reg.columns)):
    if data_log_reg.columns[j] in num_feats:
        numerical_columns.append(j)

# %%
from sklearn.model_selection import train_test_split

X_log_reg = data_log_reg

X_train, X_test, y_train, y_test = train_test_split(X_log_reg, y, test_size=0.30, random_state=150)
X_train.shape
# Out:
# (27772, 116)

# %%
from sklearn.pipeline import Pipeline, FeatureUnion, make_pipeline
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_auc_score

class Columns(BaseEstimator, TransformerMixin):
    def __init__(self, names=None):
        self.names = names

    def fit(self, X, y=None, **fit_params):
        return self

    def transform(self, X):
        return X[self.names]
    
    

pipe = Pipeline([
    ("features", FeatureUnion([
        ('numeric', make_pipeline(Columns(names=num_feats),StandardScaler())),
        ('categorical', make_pipeline(Columns(names=cat_feats),OneHotEncoder(sparse=False)))
    ])),
    #('PCA',PCA(n_components = 550,whiten=True)),
    ('logreg', LogisticRegression(C=10,penalty='l2',random_state=150))])

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('features', FeatureUnion(n_jobs=1,
#        transformer_list=[('numeric', Pipeline(memory=None,
#      steps=[('columns', Columns(names=['d_dead', 'r_dead', 'd_health_avg', 'r_health_avg', 'r1_in_d_base', 'd1_in_r_base', 'r1_in_r_base', 'd1_in_d_base', 'r2_in_d_base', 'd2_in_r_base', 'r2_in_r_ba...lty='l2', random_state=150, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False))])

# %%
predicted_log_reg = pipe.predict(X_test)
print(accuracy_score(y_test, predicted_log_reg))
print(roc_auc_score(y_test,predicted_log_reg))
# Out:
# 0.7568680164664371
# 0.7554775871218822

# %%
pipe2 = pipe = Pipeline([
    ("features", FeatureUnion([
        ('numeric', make_pipeline(Columns(names=num_feats),StandardScaler())),
        ('categorical', make_pipeline(Columns(names=cat_feats),OneHotEncoder(sparse=False)))
    ])),
    #('PCA',PCA(n_components = 550,whiten=True)),
    ('logreg', LogisticRegression(C=10,penalty='l2',random_state=150))])

# %%
pred1 = pipe.fit(X_train,y_train).predict_proba(X_train)[:,1]
pred1 = pd.DataFrame({'prediction': pred1},index=X_train.index,)
y_train = pd.DataFrame({'radiant_win': y_train},index=X_train.index)
full_df_train = pd.concat([y_train,pred1,X_train],axis=1)

# %%
full_df_train.head(2)
# Out:
#                                   radiant_win  prediction  d_dead  r_dead  \
# match_id_hash
# 39848cb4ca858a7ef6241a8bf84d2ff1         True    0.896504       1       0
# ed176a0a51906d76b113ebaf2787a17b         True    0.837707       2       1
#
#                                   d_health_avg  r_health_avg  r1_in_d_base  \
# match_id_hash
# 39848cb4ca858a7ef6241a8bf84d2ff1      0.683185      0.900596             0
# ed176a0a51906d76b113ebaf2787a17b      0.400854      0.622464             0
#
#                                   d1_in_r_base  r1_in_r_base  d1_in_d_base  \
# match_id_hash
# 39848cb4ca858a7ef6241a8bf84d2ff1             0             1             0
# ed176a0a51906d76b113ebaf2787a17b             0             0             0
#
#                                         ...         log_r_max_mana  \
# match_id_hash                           ...
# 39848cb4ca858a7ef6241a8bf84d2ff1        ...               8.094894
# ed176a0a51906d76b113ebaf2787a17b        ...               8.179113
#
#                                   log_d_max_mana  log_r_creeps_stacked  \
# match_id_hash
# 39848cb4ca858a7ef6241a8bf84d2ff1        7.809416              1.386294
# ed176a0a51906d76b113ebaf2787a17b        8.439597              0.000000
#
#                                   log_d_creeps_stacked  log_r_camps_stacked  \
# match_id_hash
# 39848cb4ca858a7ef6241a8bf84d2ff1                   0.0             0.693147
# ed176a0a51906d76b113ebaf2787a17b                   0.0             0.000000
#
#                                   log_d_camps_stacked  log_r_rune_pickups  \
# match_id_hash
# 39848cb4ca858a7ef6241a8bf84d2ff1                  0.0            2.944439
# ed176a0a51906d76b113ebaf2787a17b                  0.0            3.610918
#
#                                   log_d_rune_pickups  log_r_sen_placed  \
# match_id_hash
# 39848cb4ca858a7ef6241a8bf84d2ff1            2.772589          0.000000
# ed176a0a51906d76b113ebaf2787a17b            2.995732          1.098612
#
#                                   log_d_sen_placed
# match_id_hash
# 39848cb4ca858a7ef6241a8bf84d2ff1          0.000000
# ed176a0a51906d76b113ebaf2787a17b          1.791759
#
# [2 rows x 118 columns]

# %%
full_df_train[full_df_train['prediction']<=.05]['radiant_win'].value_counts()
full_df_train[full_df_train['prediction']>=.95]['radiant_win'].value_counts()
# Out:
# True     2224
# False      37
# Name: radiant_win, dtype: int64

# %%
full_df_train_2 = pd.concat([full_df_train[full_df_train['prediction']<.8],full_df_train[full_df_train['prediction']>.2]],join='inner')

# %%
full_df_train_2.head(1)
# Out:
#                                   radiant_win  prediction  d_dead  r_dead  \
# match_id_hash
# 39848cb4ca858a7ef6241a8bf84d2ff1         True    0.896504       1       0
#
#                                   d_health_avg  r_health_avg  r1_in_d_base  \
# match_id_hash
# 39848cb4ca858a7ef6241a8bf84d2ff1      0.683185      0.900596             0
#
#                                   d1_in_r_base  r1_in_r_base  d1_in_d_base  \
# match_id_hash
# 39848cb4ca858a7ef6241a8bf84d2ff1             0             1             0
#
#                                         ...         log_r_max_mana  \
# match_id_hash                           ...
# 39848cb4ca858a7ef6241a8bf84d2ff1        ...               8.094894
#
#                                   log_d_max_mana  log_r_creeps_stacked  \
# match_id_hash
# 39848cb4ca858a7ef6241a8bf84d2ff1        7.809416              1.386294
#
#                                   log_d_creeps_stacked  log_r_camps_stacked  \
# match_id_hash
# 39848cb4ca858a7ef6241a8bf84d2ff1                   0.0             0.693147
#
#                                   log_d_camps_stacked  log_r_rune_pickups  \
# match_id_hash
# 39848cb4ca858a7ef6241a8bf84d2ff1                  0.0            2.944439
#
#                                   log_d_rune_pickups  log_r_sen_placed  \
# match_id_hash
# 39848cb4ca858a7ef6241a8bf84d2ff1            2.772589               0.0
#
#                                   log_d_sen_placed
# match_id_hash
# 39848cb4ca858a7ef6241a8bf84d2ff1               0.0
#
# [1 rows x 118 columns]

# %%
y_train2 = full_df_train_2['radiant_win']
X_train2 = full_df_train_2.drop('radiant_win',axis=1)

# %%
pipe2.fit(X_train2,y_train2)
# Out:
# Pipeline(memory=None,
#      steps=[('features', FeatureUnion(n_jobs=1,
#        transformer_list=[('numeric', Pipeline(memory=None,
#      steps=[('columns', Columns(names=['d_dead', 'r_dead', 'd_health_avg', 'r_health_avg', 'r1_in_d_base', 'd1_in_r_base', 'r1_in_r_base', 'd1_in_d_base', 'r2_in_d_base', 'd2_in_r_base', 'r2_in_r_ba...lty='l2', random_state=150, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False))])

# %%
pipe2_predict = pipe.predict(X_test)
print(accuracy_score(y_test, pipe2_predict))
print(roc_auc_score(y_test,pipe2_predict))
# Out:
# 0.7514912207006637
# 0.751430560764196

# %%
pred2 = pipe2.fit(X_train2,y_train2).predict_proba(X_train2)[:,1]
pred2 = pd.DataFrame({'prediction2': pred2},index=X_train2.index,)
y_train2 = pd.DataFrame({'radiant_win': y_train2},index=X_train2.index)
full_df_train3 = pd.concat([y_train2,pred2,X_train2],axis=1)

# %%
full_df_train3.head(15)
# Out:
#                                   radiant_win  prediction2  prediction  \
# match_id_hash
# 39848cb4ca858a7ef6241a8bf84d2ff1         True     0.886118    0.896504
# ed176a0a51906d76b113ebaf2787a17b         True     0.850575    0.837707
# b910a596a48ef661afa283610c7c5aa5        False     0.716004    0.806784
# ac831d981032ed9e63c2e9dc824d9d65         True     0.941232    0.932697
# 8ff6df8f40355a95e85b3b45b0ef2536         True     0.908050    0.923459
# 56f0eeb4999ab2bc5ca00d23004ff197         True     0.827629    0.871263
# 5025076e190a4c60f6fdbe8a35de303e         True     0.935075    0.923505
# 80bd11690dc421970d29f5aaaeb1a575         True     0.993245    0.988314
# 52e6fceac0187872532709eaa5568cb8         True     0.883732    0.908542
# 56f2b93262ebcbe7c245cb29661b72ac        False     0.838031    0.858696
# 7446f8d437495256a5fe955da76e0395         True     0.816973    0.844073
# 01548e5f2974d4f5ebc6573c5a68158e         True     0.992294    0.994706
# b41d1101e3f0929b2993d55ff75d6d2e         True     0.957636    0.937764
# bc582ee7b9fd01064f58d87ec8f00fd1         True     0.933180    0.933229
# c3a71aee37f8f2b735ceab57bea72379         True     0.980409    0.979425
#
#                                   d_dead  r_dead  d_health_avg  r_health_avg  \
# match_id_hash
# 39848cb4ca858a7ef6241a8bf84d2ff1       1       0      0.683185      0.900596
# ed176a0a51906d76b113ebaf2787a17b       2       1      0.400854      0.622464
# b910a596a48ef661afa283610c7c5aa5       0       0      0.894429      0.834420
# ac831d981032ed9e63c2e9dc824d9d65       2       0      0.424201      0.394520
# 8ff6df8f40355a95e85b3b45b0ef2536       0       4      0.981229      0.178348
# 56f0eeb4999ab2bc5ca00d23004ff197       3       2      0.370000      0.559979
# 5025076e190a4c60f6fdbe8a35de303e       2       0      0.599130      0.952356
# 80bd11690dc421970d29f5aaaeb1a575       3       1      0.400000      0.609846
# 52e6fceac0187872532709eaa5568cb8       2       0      0.600000      0.735241
# 56f2b93262ebcbe7c245cb29661b72ac       0       0      0.804171      0.666091
# 7446f8d437495256a5fe955da76e0395       1       2      0.442680      0.288047
# 01548e5f2974d4f5ebc6573c5a68158e       0       0      1.000000      0.935491
# b41d1101e3f0929b2993d55ff75d6d2e       1       1      0.483523      0.682423
# bc582ee7b9fd01064f58d87ec8f00fd1       0       0      0.812192      0.924229
# c3a71aee37f8f2b735ceab57bea72379       2       0      0.406252      0.969272
#
#                                   r1_in_d_base  d1_in_r_base  r1_in_r_base  \
# match_id_hash
# 39848cb4ca858a7ef6241a8bf84d2ff
# 01548e5f2974d4f5ebc6573c5a68158e          1.098612
# b41d1101e3f0929b2993d55ff75d6d2e          0.000000
# bc582ee7b9fd01064f58d87ec8f00fd1          1.098612
# c3a71aee37f8f2b735ceab57bea72379          1.609438
#
# [15 rows x 119 columns]

# %%
full_df_train_3 = pd.concat([full_df_train[full_df_train3['prediction']>=.8],full_df_train3[full_df_train['prediction']<=.2]])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-af87043a8b24> in <module>
# ----> 1 full_df_train_3 = pd.concat([full_df_train[full_df_train3['prediction']>=.8],full_df_train3[full_df_train['prediction']<=.2]])
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
# -> 2684             return self._getitem_frame(key)
#    2685         elif is_mi_columns:
#    2686             return self._getitem_multilevel(key)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_frame(self, key)
#    2766         if key.values.size and not is_bool_dtype(key.values):
#    2767             raise ValueError('Must pass DataFrame with boolean values only')
# -> 2768         return self.where(key)
#    2769
#    2770     def query(self, expr, inplace=False, **kwargs):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in where(self, cond, other, inplace, axis, level, errors, try_cast, raise_on_error)
#    7770         other = com._apply_if_callable(other, self)
#    7771         return self._where(cond, other, inplace, axis, level,
# -> 7772                            errors=errors, try_cast=try_cast)
#    7773
#    7774     @Appender(_shared_docs['where'] % dict(_shared_doc_kwargs, cond="False",
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _where(self, cond, other, inplace, axis, level, errors, try_cast)
#    7630                                         errors=errors,
#    7631                                         try_cast=try_cast, axis=block_axis,
# -> 7632                                         transpose=self._AXIS_REVERSED)
#    7633
#    7634             return self._constructor(new_data).__finalize__(self)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in where(self, **kwargs)
#    3682
#    3683     def where(self, **kwargs):
# -> 3684         return self.apply('where', **kwargs)
#    3685
#    3686     def eval(self, **kwargs):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3576                     axis = getattr(obj, '_info_axis_number', 0)
#    3577                     kwargs[k] = obj.reindex(b_items, axis=axis,
# -> 3578                                             copy=align_copy)
#    3579
#    3580             kwargs['mgr'] = self
#
# /anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     185         @wraps(func)
#     186         def wrapper(*args, **kwargs):
# --> 187             return func(*args, **kwargs)
#     188
#     189         if not PY2:
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in reindex(self, *args, **kwargs)
#    3564         kwargs.pop('axis', None)
#    3565         kwargs.pop('labels', None)
# -> 3566         return super(DataFrame, self).reindex(**kwargs)
#    3567
#    3568     @Appender(_shared_docs['reindex_axis'] % _shared_doc_kwargs)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in reindex(self, *args, **kwargs)
#    3687         # perform the reindex on the axes
#    3688         return self._reindex_axes(axes, level, limit, tolerance, method,
# -> 3689                                   fill_value, copy).__finalize__(self)
#    3690
#    3691     def _reindex_axes(self, axes, level, limit, tolerance, method, fill_value,
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    3494         if columns is not None:
#    3495             frame = frame._reindex_columns(columns, method, copy, level,
# -> 3496                                            fill_value, limit, tolerance)
#    3497
#    3498         index = axes['index']
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _reindex_columns(self, new_columns, method, copy, level, fill_value, limit, tolerance)
#    3519         return self._reindex_with_indexers({1: [new_columns, indexer]},
#    3520                                            copy=copy, fill_value=fill_value,
# -> 3521                                            allow_dups=False)
#    3522
#    3523     def _reindex_multi(self, axes, copy, fill_value):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _reindex_with_indexers(self, reindexers, fill_value, copy, allow_dups)
#    3808                                                 fill_value=fill_value,
#    3809                                                 allow_dups=allow_dups,
# -> 3810                                                 copy=copy)
#    3811
#    3812         if copy and new_data is self._data:
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy)
#    4412         # some axes don't allow reindexing with dups
#    4413         if not allow_dups:
# -> 4414             self.axes[axis]._can_reindex(indexer)
#    4415
#    4416         if axis >= self.ndim:
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in _can_reindex(self, indexer)
#    3574         # trying to reindex on an axis with duplicates
#    3575         if not self.is_unique and len(indexer):
# -> 3576             raise ValueError("cannot reindex from a duplicate axis")
#    3577
#    3578     def reindex(self, target, method=None, level=None, limit=None,
#
# ValueError: cannot reindex from a duplicate axis

# %%
pipe.fit(X_log_reg,y)
# Out:
# Pipeline(memory=None,
#      steps=[('features', FeatureUnion(n_jobs=1,
#        transformer_list=[('numeric', Pipeline(memory=None,
#      steps=[('columns', Columns(names=['d_dead', 'r_dead', 'd_health_avg', 'r_health_avg', 'r1_in_d_base', 'd1_in_r_base', 'r1_in_r_base', 'd1_in_d_base', 'r2_in_d_base', 'd2_in_r_base', 'r2_in_r_ba...lty='l2', random_state=150, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False))])

# %%
test_data =  pd.read_csv('new_feat_test_small.csv', index_col ='match_id_hash')
test_data.drop(col_to_drop,axis=1,inplace=True)
test_data.shape
# Out:
# (10000, 116)

# %%
X_sub_log_reg = test_data
y_test_pred_log_reg = pipe.predict_proba(X_sub_log_reg)[:, 1]
y_test_pred_log_reg
y_test_pred_log_reg = pd.DataFrame({'radiant_win_prob': y_test_pred_log_reg},index=test_data.index)

# %%
full_sub1 = pd.concat([X_sub_log_reg,y_test_pred_log_reg],axis=1)
full_sub1.head(2)
# Out:
#                                   d_dead  r_dead  d_health_avg  r_health_avg  \
# match_id_hash
# 30cc2d778dca82f2edb568ce9b585caa       0       0      0.882700      0.967868
# 70e5ba30f367cea48793b9003fab9d38       1       0      0.656069      0.969930
#
#                                   r1_in_d_base  d1_in_r_base  r1_in_r_base  \
# match_id_hash
# 30cc2d778dca82f2edb568ce9b585caa             0             0             0
# 70e5ba30f367cea48793b9003fab9d38             0             0             0
#
#                                   d1_in_d_base  r2_in_d_base  d2_in_r_base  \
# match_id_hash
# 30cc2d778dca82f2edb568ce9b585caa             0             0             0
# 70e5ba30f367cea48793b9003fab9d38             1             0             0
#
#                                         ...         log_d_max_mana  \
# match_id_hash                           ...
# 30cc2d778dca82f2edb568ce9b585caa        ...               7.283235
# 70e5ba30f367cea48793b9003fab9d38        ...               8.006931
#
#                                   log_r_creeps_stacked  log_d_creeps_stacked  \
# match_id_hash
# 30cc2d778dca82f2edb568ce9b585caa              0.000000              0.000000
# 70e5ba30f367cea48793b9003fab9d38              3.258097              1.791759
#
#                                   log_r_camps_stacked  log_d_camps_stacked  \
# match_id_hash
# 30cc2d778dca82f2edb568ce9b585caa             0.000000             0.000000
# 70e5ba30f367cea48793b9003fab9d38             1.609438             1.098612
#
#                                   log_r_rune_pickups  log_d_rune_pickups  \
# match_id_hash
# 30cc2d778dca82f2edb568ce9b585caa            1.098612            1.098612
# 70e5ba30f367cea48793b9003fab9d38            3.044522            2.833213
#
#                                   log_r_sen_placed  log_d_sen_placed  \
# match_id_hash
# 30cc2d778dca82f2edb568ce9b585caa          0.000000          0.000000
# 70e5ba30f367cea48793b9003fab9d38          1.386294          1.098612
#
#                                   radiant_win_prob
# match_id_hash
# 30cc2d778dca82f2edb568ce9b585caa          0.324375
# 70e5ba30f367cea48793b9003fab9d38          0.982669
#
# [2 rows x 117 columns]

# %%
full_sub1['radiant_win_prob'].hist()

# %%
X_test2 = full_sub1[full_sub1['radiant_win_prob'] > .02]
X_test2 = X_test2[X_test2['radiant_win_prob'] < 0.8]
X_test2.drop('radiant_win_prob',inplace=True,axis=1)

# %%
X_test2.shape
# Out:
# (7319, 116)

# %%
df_submission = pd.DataFrame({'radiant_win_prob': y_test_pred_log_reg},index=test_data.index)

import datetime
submission_filename = 'submission_{}.csv'.format(
    datetime.datetime.now().strftime('%Y-%m-%d_%H-%M-%S'))
df_submission.to_csv(submission_filename)
print('Submission saved to {}'.format(submission_filename))

df_submission.head(10)
# Out:
# Submission saved to submission_2019-11-17_09-40-12.csv
#                                   radiant_win_prob
# match_id_hash
# 30cc2d778dca82f2edb568ce9b585caa          0.324375
# 70e5ba30f367cea48793b9003fab9d38          0.982669
# 4d9ef74d3a2025d79e9423105fd73d41          0.945856
# 2bb79e0c1eaac1608e5a09c8e0c6a555          0.854048
# bec17f099b01d67edc82dfb5ce735a43          0.188703
# 038acbb47d9eb54c11962d07cce8d829          0.062399
# b891f03bb2a86d78b84043437fc95e04          0.959600
# ff898afdb5bb5c7163bde45a009503f7          0.104206
# 72e6b1c31c718c0806f9aaeb8b7290a9          0.574646
# abd97ab60ceca3ae6f00a28baea8a43c          0.590057

# %%
df_submission.shape
# Out:
# (10000, 1)
